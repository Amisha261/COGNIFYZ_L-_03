# %% [markdown]
# # Price range distribution

# %% [markdown]
# ## 1. Importing necassary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Dataset .csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
price_range=data["Price range"].value_counts()
price_range
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
restaurants=len(data)
restaurants
# Out:
# 9551

# %%
price_range_percentage=(price_range/restaurants)*100
price_range_percentage
# Out:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: count, dtype: float64

# %%
price_range.plot(kind='bar', color='blue')
plt.title('Distribution of Price Ranges Among Restaurants')
plt.xlabel('Price Range')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## SUMMARY

# %% [markdown]
# Load the Dataset:
#
# - Load the dataset containing the restaurant data into your analysis environment (e.g., Python).
#
# Inspect the Dataset:
#
# - Inspect the dataset to understand its structure and identify the column that contains the price range information.
#
# Count the Occurrences of Each Price Range:
#
# - Count how many times each price range appears in the dataset.
#
# Calculate the Percentages:
#
# - Calculate the percentage of restaurants that fall into each price range category.
#
# Create a Histogram or Bar Chart:
#
# - Use a plotting library to create the visualization
